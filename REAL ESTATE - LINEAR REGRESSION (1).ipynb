# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# !pip install pandas

# %%
dataset=pd.read_csv("C:/Real estate.csv")

# %%
dataset.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
dataset.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
! pip install sklearn

# %%
dataset.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
dataset=pd.read_csv("C:/Real estate.csv")
x= dataset.iloc[:, :-1].values
y= dataset.iloc[:, :-1].values

# %%
#from sklearn.cross_validate import train_test_split
from sklearn.model_selection import  train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([[ 3.57000000e+02,  2.01283300e+03,  1.03000000e+01,
#          2.11447300e+02,  1.00000000e+00,  2.49741700e+01,
#          1.21529990e+02],
#        [ 1.71000000e+02,  2.01333300e+03,  2.40000000e+01,
#          4.52768700e+03, -1.18556645e-14,  2.49474100e+01,
#          1.21496280e+02],
#        [ 2.25000000e+02,  2.01333300e+03,  3.45000000e+01,
#          3.24941900e+02,  6.00000000e+00,  2.49781400e+01,
#          1.21541700e+02],
#        [ 3.32000000e+02,  2.01333300e+03,  2.56000000e+01,
#          4.51969000e+03, -1.07924082e-14,  2.49482600e+01,
#          1.21495870e+02],
#        [ 3.07000000e+02,  2.01350000e+03,  1.44000000e+01,
#          1.69980300e+02,  1.00000000e+00,  2.49736900e+01,
#          1.21529790e+02],
#        [ 3.26000000e+02,  2.01308300e+03,  3.66000000e+01,
#          4.88819300e+02,  8.00000000e+00,  2.49701500e+01,
#          1.21544940e+02],
#        [ 1.51000000e+02,  2.01325000e+03,  3.58000000e+01,
# ...

# %%
#VISUALSING THE TRAINING SET RESULTS

plt.scatter(x_train,y_train,color="blue")
plt.plot(x_train,regressor.predict(x_train),color="orange",linewidth=2)
plt.title('No VS Y house price of unit area')
plt.xlabel('Y house price of unit area')
plt.ylabel('No ')
plt.show()

# %%
#VISUALSING THE Test SET RESULTS

plt.scatter(x_test,y_test,color="orange")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title('No VS Y house price of unit area {test_set}',color="red")
plt.xlabel('Y house price of unit area',color='red')
plt.ylabel('No',color="green")
plt.show()

# %%
plt.scatter(dataset['No'], dataset['Y house price of unit area'],color ='green')

plt.title('SCATTER PLOT')
plt.xlabel('Y house price of unit area')
plt.ylabel('No')
# Out:
# Text(0, 0.5, 'No')

# %%
plt.bar(dataset['No'], dataset['Y house price of unit area'],color='orange')
plt.title('BAR PLOT')
plt.xlabel('Y house price of unit area')
plt.ylabel('No')
# Out:
# Text(0, 0.5, 'No')

# %%
sns.boxplot(data=dataset,y='X1 transaction date',color='violet')
# Out:
# <AxesSubplot:ylabel='X1 transaction date'>

# %%
sns.boxplot(data=dataset,y='X2 house age', color='violet')
# Out:
# <AxesSubplot:ylabel='X2 house age'>

# %%
sns.boxplot(data=dataset,y='X3 distance to the nearest MRT station', color='violet')
# Out:
# <AxesSubplot:ylabel='X3 distance to the nearest MRT station'>

# %%
sns.boxplot(data=dataset,y='X4 number of convenience stores',color='violet')
# Out:
# <AxesSubplot:ylabel='X4 number of convenience stores'>

# %%
sns.boxplot(data=dataset,y='X5 latitude',color='violet')
# Out:
# <AxesSubplot:ylabel='X5 latitude'>

# %%
dataset['X5 latitude'].describe()
# Out:
# count    414.000000
# mean      24.969030
# std        0.012410
# min       24.932070
# 25%       24.963000
# 50%       24.971100
# 75%       24.977455
# max       25.014590
# Name: X5 latitude, dtype: float64

# %%
sns.boxplot(data=dataset,y='X6 longitude',color='violet')
# Out:
# <AxesSubplot:ylabel='X6 longitude'>

# %%
dataset[dataset['X6 longitude']>121.56]
# Out:
#       No  X1 transaction date  X2 house age  \
# 184  185             2012.750          14.1
# 187  188             2013.000           8.9
# 307  308             2012.833          10.3
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 184                                2615.465                                0
# 187                                3078.176                                0
# 307                                3079.890                                0
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 184     24.95495     121.56174                        21.8
# 187     24.95464     121.56627                        22.0
# 307     24.95460     121.56627                        24.7

# %%
sns.boxplot(data=dataset,y='Y house price of unit area',color='violet')
# Out:
# <AxesSubplot:ylabel='Y house price of unit area'>

# %%
sns.heatmap(dataset.corr(),annot=True,color='blue')
# Out:
# <AxesSubplot:>
